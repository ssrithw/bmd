# %% [markdown]
# <h1 align="center"><b>Bone Mineral Density Prediction Challenge - Semester 01, 2026</b></h1>
# <h2 align="center">CSG2341 Artificial Intelligence 1</h2>
# <h3 align="center">Lecturer: Mr. Niroshan Balasuriya</h3>
# <h3 align="center">Group: NIR-01</h3>
# <h4 align="center">Anuki Senanayakalage (Student ID 10712258)</h4>
# <h4 align="center">Disara Ambagala (Student ID 10745176)</h4>
# <h4 align="center">Shivangi Sritharan (Student ID 10712234)</h4>
# <br>
#
# ---
# add a real intro/description here i'm lazy
#
# ---
# <h2><b>Notebook Structure</b></h2>
# <table style="display: block; margin-right: auto;">
#   <tr><th>#</th><th>Section</th></tr>
#   <tr><td>1</td><td><a href="#1---Imports">Imports</a></td></tr>
#   <tr><td>2</td><td><a href="#2---File-Paths">File Paths</a></td></tr>
#   <tr><td>3</td><td><a href="#3---Load-Metadata">Load Metadata</a></td></tr>
#   <tr><td>4</td><td><a href="#4---Organise-Images-into-Folders">Organise Images into Folders</a></td></tr>
#   <tr><td>5</td><td><a href="#5---Exploratory-Data-Analysis">Exploratory Data Analysis</a></td></tr>
#   <tr><td>6</td><td><a href="#6---Pre-processing-Pipeline">Pre-processing Pipeline</a></td></tr>
#   <tr><td>7</td><td><a href="#7---Combine-Image-Features-and-Metadata">Combine Image Features and Metadata</a></td></tr>
#   <tr><td>8</td><td><a href="#8---Pipeline-Scaling">Pipeline Scaling</a></td></tr>
#   <tr><td>9</td><td><a href="#9---Regression-Evaluation">Regression Evaluation</a></td></tr>
#   <tr><td>10</td><td><a href="#10---Diagnostic-Plots">Diagnostic Plots</a></td></tr>
#   <tr><td>11</td><td><a href="#11---Convert-Predicted-BMD">Convert Predicted BMD</a></td></tr>
#   <tr><td>12</td><td><a href="#12---Evaluation">Evaluation</a></td></tr>
# </table>

# %%
# [Shivangi] i'm only keeping this here because i can't figure out where to put it, but i suggest deleting it

# Osteoporosis Detection — Pipeline
# Anuki Kithara
# Date: 28/04/2026
# Models: SVR, KNN, Random Forest

# %% [markdown]
# <br>

# %% [markdown]
# # 1 - Imports
#
# This section is used to set up the libraries needed to run our notebook.
#
# We first import standard Python modules such as `os` and `pathlib` for file handling. We then import data processing libraries such as `numpy` and `pandas` as well as data visualization libraries such as `matplotlib` to support exploratory data analysis.
#
# For image processing, the code uses `cv2` (OpenCV) along with `skimage` functions such as Histogram of Oriented Gradients (HOG). These are used to extract meaningful features from image data and aid in pre-processing the images.
#
# The machine learning pipeline is built using `scikit-learn`. We import preprocessing tools such as `StandardScaler` and `LabelEncoder`, modules for dimensionality reduction, and modeling with Support Vector Regression. Model selection and evaluation are supported with `GridSearchCV` and `KFold` for cross-validation. Additionally, performance metrics such as MAE, MSE, R², confusion matrix, and classification reports are imported.
#
# Finally, some configuration settings are applied. Warnings are suppressed for cleaner output, and Matplotlib and Seaborn are configured to create visually consistent plots. We also set a fixed random seed to ensure reproducibility across runs.

# %%
import os
import shutil
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import loguniform # for loguniform

# Image I/O and feature extraction
import cv2
from skimage.feature import hog
from skimage.measure import moments_hu, moments_central, moments_normalized, moments

# Modelling
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, KFold, RandomizedSearchCV
from sklearn.metrics import (
    mean_absolute_error, mean_squared_error, r2_score,
    confusion_matrix, balanced_accuracy_score, classification_report
)

#import warnings
#warnings.filterwarnings("ignore")

# Same seed everywhere
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# Plot style
sns.set_style("whitegrid")
plt.rcParams["figure.dpi"] = 100

# %%
# %matplotlib inline

# %% [markdown]
# <br>

# %% [markdown]
# # 2 - File Paths
#
# This section defines all the directory paths and global constants used throughout the notebook.
#
# - `IMAGE_DIR` is the root folder containing all X-ray image data.
# - `TRAIN_CSV` and `VAL_CSV` are constants for the train and val CSV files provided with the dataset.
# - `TRAIN_IMAGE_DIR` and `VAL_IMAGE_DIR` are the destination folders for images that will be populated in Section 4.
# - `IMG_SIZE` - every image is resized to this square resolution before feature extraction.
# - `HIST_BINS` is the number of bins used when computing a grayscale intensity histogram.
#
# **Please edit the three paths at the top of the code cell to match your local folder layout before running anything else.**

# %%
# ============ Please modify these 3 values according to your folder structure. ============

IMAGE_DIR  = Path("X-rays") # folder path for images
TRAIN_CSV  = Path("train_groundtruth_BMD.csv") # path for the training metadata csv
VAL_CSV    = Path("train_groundtruth_BMD.csv") # path for the validation metadata csv


# This code looks for folders named train_images and val_images and builds them if they don't exist.
TRAIN_IMAGE_DIR = Path("train_images")
VAL_IMAGE_DIR   = Path("val_images")

# Image and feature settings
IMG_SIZE = 128                # resize images to 128x128
HIST_BINS = 64                # grayscale histogram bins

# T-score reference
REF_BMD = 0.86
REF_SD  = 0.12

# Checks if the files exist
assert TRAIN_CSV.exists(), "Training CSV not found"
assert VAL_CSV.exists(), "Validation CSV not found"
assert IMAGE_DIR.exists(), "Image folder not found"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_1503/3836097639.py in <cell line: 0>()
#      21 assert TRAIN_CSV.exists(), "Training CSV not found"
#      22 assert VAL_CSV.exists(), "Validation CSV not found"
# ---> 23 assert IMAGE_DIR.exists(), "Image folder not found"
#
# AssertionError: Image folder not found

# %% [markdown]
# # 3 - Load Metadata
#
# The two CSV files containing metadata for training and validation datasets are read into pandas DataFrames. Each CSV file includes the image filename, the target BMD value and patient related information.
#
# After loading the files, the first few rows and columns are printed to confirm that data has been imported correctly.

# %%
train_df = pd.read_csv(TRAIN_CSV)
val_df   = pd.read_csv(VAL_CSV)

# Checks dimensions and columns
print(f"Train: {train_df.shape[0]} rows, {train_df.shape[1]} columns")
print(f"Val:   {val_df.shape[0]} rows, {val_df.shape[1]} columns")
train_df.head()
# Out:
# Train: 377 rows, 4 columns
# Val:   377 rows, 4 columns
#                             image  interview_age Gender       BMD
# 0  6.E.1_9021102_20090706_001.png            888      F  0.696443
# 1  6.E.1_9030718_20090824_001.png            960      F  1.201649
# 2  6.E.1_9047519_20090720_001.png            876      F  0.945649
# 3  6.C.1_9048789_20090226_001.png            780      F  0.927137
# 4  6.E.1_9054972_20090911_001.png            828      F  0.987368

# %% [markdown]
# # 4 - Organise Images into Folders
#
# The dataset was provided to us with all the images in one directory named "X-rays". For better visualisation, we decided to separate out the images into dedicated folders based on how they will be used in the pipeline. This section copies each image into a dedicated `train_images/` or `val_images/` subdirectory based on the split recorded in the metadata CSV files.
#
# **Please run this cell ONCE. On subsequent runs, comment out the cell to avoid additional disk operations.**

# %%
# Uncomment and run once to organise images into train and val folders
# Then comment this block again.

import shutil

def organise_split(source_dir, dest_dir, df):
    dest_dir.mkdir(exist_ok=True)

    for filename in df["image"]:
        src = source_dir / filename
        dst = dest_dir / filename

        if src.exists() and not dst.exists():
            shutil.copy2(src, dst)


organise_split(IMAGE_DIR, TRAIN_IMAGE_DIR, train_df)
organise_split(IMAGE_DIR, VAL_IMAGE_DIR, val_df)

print("Image folders organised.")
# Out:
# Image folders organised.

# %% [markdown]
# # 5 - Exploratory Data Analysis
#
# In this section, we will analyze metadata from the data that was used for the training process. The dataset under consideration contains information about 250 people who have their age (in months), gender and Bone Mineral Density values recorded. Visualization techniques are going to be applied for investigating the mentioned characteristics of our dataset, including gender distribution, BMD distribution, class balance between Normal and Low BMD patiens, and the relationship between age and BMD values.

# %%
# add T-score column
train_df["t_score"], val_df["t_score"] = (train_df["BMD"] - 0.86)/0.12, (val_df["BMD"] - 0.86)/0.12

# add binary label (0 = Normal, 1 = Low BMD)
train_df["low_bmd"], val_df["low_bmd"] = (train_df["t_score"] < -1), (val_df["t_score"] < -1)

train_df.head()

# use Pandas' hist() method to plot the histograms of each numerical column vs number of entries
# you can modify the bins and figsize, and also look up more arguments for the method
train_df.hist(bins=50, figsize=(20,15))

# actually display the plot
plt.show()

# %% [markdown]
# <br>

# %%
# display the first 8 training images so we can confirm they loaded correctly

# train_df.head() is the first x rows of the data frame named train_df.
# head() usually defaults to 5 but we set 8 here
sample_rows = train_df.head(8)

# creates a 2x4 grid of 8 subplots (2 rows, 4 columns)
# and sets the figure size to 14x7
# you can change 2, 4 and the values in figsize (14, 7) to see what happens
fig, axes = plt.subplots(2, 4, figsize=(14, 7))

# iterate simultaneously through the grid set up with plt.subplots and the data frame in sample_rows
for ax, (_, row) in zip(axes.flatten(), sample_rows.iterrows()):
    # create path to the image by combining the training folder name and the name of the image as defined in the csv
    img_path = TRAIN_IMAGE_DIR / row["image"]

    if img_path.exists():
        # look for the image defined by img_path
        # you can also look for other arguments to add here, such as cv2.IMREAD_GRAYSCALE (google it lol)
        img = cv2.imread(str(img_path))
        # resize image to the size set in Section 2
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        # pair it with a subplot
        # you can also look for other arguments to add here, such as cmap (google it lol)
        ax.imshow(img)
        # give the subplot a title (we just display its BMD value but you can set it to the image name or whatever you'd like)
        ax.set_title(f"BMD={row['BMD']:.3f}", fontsize=9)

    # display this if no image is found. you can display the plot without an if/else loop but if any errors occur it will stop the whole notebook
    else:
        ax.set_title("Warning: Image not found!", color="red", fontsize=9)

    # hides the grid components. you can comment this out or delete it to see what happens
    ax.axis("off")

# give the plot a title
plt.suptitle("Sample training X-rays (resized to 128×128)", fontsize=12)

# adjust padding so the subplots automatically fit into the space instead of overflowing or overlapping
# you can remove or comment this out to see what happens.
plt.tight_layout()

# actually display the plot
plt.show()

# %%
# [Disara] Gender distribution of training data
gender_counts = train_df['Gender'].value_counts()
plt.figure(figsize=(6,4))
plt.bar(gender_counts.index, gender_counts.values, color=['steelblue','salmon'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Number of Patients')
plt.tight_layout()
plt.show()

# %%
# [Disara] Class distribution - Normal vs Low BMD
bmd_counts = train_df['low_bmd'].value_counts()
plt.figure(figsize=(6,4))
plt.bar(['Normal','Low BMD'], bmd_counts.values, color=['green','red'])
plt.title('Normal vs Low BMD Distribution')
plt.xlabel('BMD Category')
plt.ylabel('Number of Patients')
plt.tight_layout()
plt.show()

# %%
# [Disara] Relationship between age and BMD
plt.figure(figsize=(6,4))
plt.scatter(train_df['interview_age'], train_df['BMD'], alpha=0.5, color='steelblue')
plt.title('Age vs BMD')
plt.xlabel('Age (months)')
plt.ylabel('BMD Value')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6 - Pre-processing Pipeline
#
# <h2 style="color: red;">PIPELINE IS UNFINISHED !!!</h2>
#
# Each X-ray image is loaded in greyscale, resized to 128x128, and then described using **Histogram of Oriented Gradients (HOG)**.
#
# HOG divides the image into small cells, computes a histogram of edge orientations within each cell, and normalises across overlapping blocks. This captures local texture and edge structure while remaining robust to small changes in lighting.

# %%
def extract_image_features(image_dir: Path, df: pd.DataFrame) -> np.ndarray:
    feature_rows = []

    for filename in df["image"]:
        img_path = image_dir / filename

        # load in greyscale
        if img_path.exists():
            img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)

        # fall back to a blank image if the file is missing
        else:
            print(f"Warning: {filename} not found!")
            img = np.zeros((IMG_SIZE, IMG_SIZE), dtype=np.uint8)

        # resize to a fixed square so every feature vector has the same length
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))

        # actual HOG features
        # pixels_per_cell and cells_per_block were chosen to give ~1000 HOG features at 128×128
        hog_features = hog(
            img,
            orientations=9,
            pixels_per_cell=(16, 16),
            cells_per_block=(2, 2),
            block_norm="L2-Hys",
            feature_vector=True,
        )

        feature_rows.append(hog_features)  # if adding more, concatenate here

    return np.array(feature_rows, dtype=np.float32)

# %% [markdown]
# Simultaneously, the metadata provided in `train_groundtruth_BMD.csv` is prepared for the model. We first drop the image name and BMD columns, as the former is irrelevant and the latter contains the target values. We then encode the categorical columns into integers. Missing values are filled with a placeholder to avoid the notebook running into fatal errors.

# %%
def prepare_metadata(df: pd.DataFrame) -> np.ndarray:
    # drop image and target columns
    meta = df.drop(columns=["image", "BMD", "t_score", "low_bmd"]).copy()

    # fill with placeholder values if needed
    if meta.empty or meta.shape[1] == 0:
        return np.zeros((len(df), 0), dtype=np.float32)

    for col in meta.columns:
        if col == "Gender":
            # encode gender as integers
            meta[col] = meta[col].map({"M": 0, "F": 1})

    return meta.values.astype(np.float32)


def fill_missing_values(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    for col in df.columns:
        if df[col].dtype == object or str(df[col].dtype) == "category":
            # fill categorical columns with the most frequent value
            df[col] = df[col].fillna(df[col].mode()[0])
        else:
            # fill numerical columns with the median
            df[col] = df[col].fillna(df[col].median())

    return df

# %% [markdown]
# This cell runs the pre-processing pipeline. `extract_image_features` and `prepare_metadata` are called on both splits to produce the four feature matrices used downstream. Additionally, we print shapes to confirm that:
# * the number of rows matches the number of samples in each CSV file.
# * feature dimensions are consistent between train and validation

# %%
# run feature extraction

print("Extracting training image features...")
X_img_train = extract_image_features(TRAIN_IMAGE_DIR, train_df)
print(f"  X_img_train shape: {X_img_train.shape}")

print("Extracting validation image features...")
X_img_val   = extract_image_features(VAL_IMAGE_DIR, val_df)
print(f"  X_img_val shape:   {X_img_val.shape}")

print("Preparing training metadata...")
X_meta_train = prepare_metadata(train_df)
print(f"  X_meta_train shape: {X_meta_train.shape}")

print("Preparing validation metadata...")
X_meta_val   = prepare_metadata(val_df)
print(f"  X_meta_val shape:   {X_meta_val.shape}")

print("Feature extraction completed.")
# Out:
# Extracting training image features...
# Warning: 6.E.1_9021102_20090706_001.png not found!
# Warning: 6.E.1_9030718_20090824_001.png not found!
# Warning: 6.E.1_9047519_20090720_001.png not found!
# Warning: 6.C.1_9048789_20090226_001.png not found!
# Warning: 6.E.1_9054972_20090911_001.png not found!
# Warning: 6.E.1_9066921_20090618_001.png not found!
# Warning: 6.E.1_9071669_20091120_001.png not found!
# Warning: 6.E.1_9072956_20090619_001.png not found!
# Warning: 6.E.1_9075939_20090911_001.png not found!
# Warning: 6.E.1_9075939_20091102_001.png not found!
# Warning: 6.E.1_9081635_20090818_001.png not found!
# Warning: 6.E.1_9082159_20100305_001.png not found!
# Warning: 6.E.1_9093108_20090921_001.png not found!
# Warning: 6.E.1_9113199_20090909_001.png not found!
# Warning: 6.E.1_9179789_20091005_001.png not found!
# Warning: 6.E.1_9193863_20091026_001.png not found!
# Warning: 6.C.1_9204055_20090319_001.png not found!
# Warning: 6.E.1_9252748_20100609_001.png not found!
# Warning: 6.C.1_9267648_20090529_001.png not found!
# Warning: 6.E.1_9267719_20100129_001.png not found!
# Warning: 6.E.1_9269275_20100608_001.png not found!
# Warning: 6.E.1_9318369_20090720_001.png not found!
# Warning: 6.E.1_9318527_20091022_001.png not found!
# Warning: 6.E.1_9326801_20100513_001.png not found!
# Warning: 6.E.1_9332345_20090618_001.png not found!
# Warning: 6.E.1_9353703_20100316_001.png not found!
# Warning: 6.E.1_9354699_20100322_001.png not found!
# Warning: 6.E.1_9359678_20100304_001.png not found!
# Warning: 6.E.1_9367965_20090513_001.png not found!
# Warning: 6.E.1_9378998_20090416_001.png not found!
# Warning: 6.E.1_9380143_20090612_001.png not found!
# Warning: 6.E.1_9392537_20100504_001.png not found!
# Warning: 6.E.1_9393527_20100525_001.png not found!
# Warning: 6.E.1_9405154_20090515_001.png not found!
# Warning: 6.E.1_9421492_20091105_001.png not found!
# Warning: 6.E.1_9423500_20090924_001.png not found!
# Warning: 6.E.1_9441528_20090811_001.png not found!
# Warning: 6.E.1_9451499_20090831_001.png not found!
# Warning: 6.E.1_9454284_20100305_001.png not found!
# Warning: 6.E.1_9463310_20090702_001.png not found!
# Warning: 6.E.1_9484850_20100405_001.png not found!
# Warning: 6.E.1_9495881_20100412_001.png not found!
# Warning: 6.E.1_9512848_20090527_001.png not found!
# Warning: 6.E.1_9517311_20090610_001.png not found!
# Warning: 6.E.1_9549139_20090515_001.png not found!
# Warning: 6.E.1_9560702_20090904_001.png not found!
# Warning: 6.E.1_9568504_20090723_001.png not found!
# Warning: 6.E.1_9574069_20090625_001.png not found!
# Warning: 6.E.1_9576572_20090811_001.png not found!
# Warning: 6.E.1_9592750_20090923_001.png not found!
# Warning: 6.E.1_9621208_20090804_001.png not found!
# Warning: 6.E.1_9627172_20091109_001.png not found!
# Warning: 6.E.1_9642569_20090928_001.png not found!
# Warning: 6.E.1_9643701_20091008_001.png not found!
# Warning: 6.E.1_9648265_20090717_001.png not found!
# Warning: 6.E.1_9746467_20090521_001.png not found!
# Warning: 6.E.1_9747567_20091013_001.png not found!
# Warning: 6.E.1_9768689_20091023_001.png not found!
# Warning: 6.E.1_9871046_20100429_001.png not found!
# Warning: 6.E.1_9873102_20100527_001.png not found!
# Warning: 6.E.1_9888515_20090505_001.png not found!
# Warning: 6.E.1_9894111_20100121_001.png not found!
# Warning: 6.E.1_9900971_20100308_001.png not found!
# Warning: 6.E.1_9905024_20100510_001.png not found!
# Warning: 6.E.1_9907544_20100416_001.png not found!
# Warning: 6.E.1_9908089_20100119_001.png not found!
# Warning: 6.E.1_9920140_20100426_001.png not found!
# Warning: 6.E.1_9946501_20100326_001.png not found!
# Warning: 6.E.1_9962749_20090629_001.png not found!
# Warning: 6.C.1_9967728_20090513_001.png not found!
# Warning: 6.E.1_9968721_20090630_001.png not found!
# Warning: 6.E.1_9973199_20090817_001.png not found!
# Warning: 6.E.1_9982186_20090608_001.png not found!
# Warning: 6.C.1_9004905_20081015_001.png not found!
# Warning: 6.C.1_9029913_20090219_001.png not found!
# Warning: 6.E.1_9044005_20090804_001.png not found!
# Warning: 6.E.1_9049507_20090930_001.png not found!
# Warning: 6.C.1_9076604_20080923_001.png not found!
# Warning: 6.C.1_9085290_20080819_001.png not found!
# Warning: 6.C.1_9088345_20090127_001.png not found!
# Warning: 6.C.1_9102297_20081002_001.png not found!
# Warning: 6.C.1_9102858_20090225_001.png not found!
# Warning: 6.C.1_9103365_20090206_001.png not found!
# Warning: 6.C.1_9103449_20090217_001.png not found!
# Warning: 6.C.1_9125977_20090223_001.png not found!
# Warning: 6.C.1_9134955_20090430_001.png not found!
# Warning: 6.C.1_9138965_20090428_001.png not found!
# Warning: 6.E.1_9155218_20100127_001.png not found!
# Warning: 6.C.1_9155449_20081029_001.png not found!
# Warning: 6.C.1_9210505_20090318_001.png not found!
# Warning: 6.C.1_9239552_20090130_001.png not found!
# Warning: 6.C.1_9273964_20090218_001.png not found!
# Warning: 6.C.1_9328376_20090224_001.png not found!
# Warning: 6.C.1_9332085_20081114_001.png not found!
# Warning: 6.C.1_9346354_20090325_001.png not found!
# Warning: 6.C.1_9355257_20090402_001.png not found!
# Warning: 6.C.1_9357383_20080916_001.png not found!
# Warning: 6.C.1_9372390_20081020_001.png not found!
# Warning: 6.C.1_9384158_20090303_001.png not found!
# Warning: 6.C.1_9390719_20081016_001.png not found!
# Warning: 6.C.1_9392241_20080902_001.png not found!
# Warning: 6.C.1_9414263_20090306_001.png not found!
# Warning: 6.E.1_9417544_20100604_001.png not found!
# Warning: 6.C.1_9434150_20090209_001.png not found!
# Warning: 6.C.1_9436383_20081003_001.png not found!
# Warning: 6.C.1_9454239_20080721_001.png not found!
# Warning: 6.C.1_9505796_20081119_001.png not found!
# Warning: 6.C.1_9519268_20090115_001.png not found!
# Warning: 6.C.1_9532533_20080912_001.png not found!
# Warning: 6.C.1_9542088_20080915_001.png not found!
# Warning: 6.C.1_9552108_20090316_001.png not found!
# Warning: 6.E.1_9552630_20090812_001.png not found!
# Warning: 6.C.1_9556608_20081201_001.png not found!
# Warning: 6.C.1_9557040_20080805_001.png not found!
# Warning: 6.C.1_9575145_20081112_001.png not found!
# Warning: 6.C.1_9585175_20090312_001.png not found!
# Warning: 6.C.1_9597680_20081001_001.png not found!
# Warning: 6.C.1_9599539_20080909_001.png not found!
# Warning: 6.C.1_9606507_20081023_001.png not found!
# Warning: 6.C.1_9615507_20080731_001.png not found!
# Warning: 6.C.1_9616501_20080911_001.png not found!
# Warning: 6.C.1_9622603_20080904_001.png not found!
# Warning: 6.C.1_9638953_20080911_001.png not found!
# Warning: 6.C.1_9639088_20090210_001.png not found!
# Warning: 6.C.1_9642550_20081002_001.png not found!
# Warning: 6.C.1_9643944_20080814_001.png not found!
# Warning: 6.C.1_9653966_20080904_001.png not found!
# Warning: 6.C.1_9662112_20081002_001.png not found!
# Warning: 6.C.1_9667637_20090116_001.png not found!
# Warning: 6.C.1_9682254_20090212_001.png not found!
# Warning: 6.C.1_9684122_20080902_001.png not found!
# Warning: 6.C.1_9686777_20081110_001.png not found!
# Warning: 6.C.1_9691663_20081114_001.png not found!
# Warning: 6.C.1_9693161_20080908_001.png not found!
# Warning: 6.C.1_9727780_20080918_001.png not found!
# Warning: 6.C.1_9740440_20081215_001.png not found!
# Warning: 6.C.1_9743354_20080909_001.png not found!
# Warning: 6.C.1_9745458_20081020_001.png not found!
# Warning: 6.C.1_9751401_20081022_001.png not found!
# Warning: 6.C.1_9757418_20081031_001.png not found!
# Warning: 6.C.1_9758941_20081030_001.png not found!
# Warning: 6.C.1_9761431_20090114_001.png not found!
# Warning: 6.C.1_9771624_20090109_001.png not found!
# Warning: 6.C.1_9785604_20081010_001.png not found!
# Warning: 6.C.1_9789095_20081117_001.png not found!
# Warning: 6.C.1_9790623_20081013_001.png not found!
# Warning: 6.C.1_9818359_20090105_001.png not found!
# Warning: 6.C.1_9824005_20080820_001.png not found!
# Warning: 6.C.1_9845361_20081008_001.png not found!
# Warning: 6.C.1_9866291_20081119_001.png not found!
# Warning: 6.C.1_9884303_20081029_001.png not found!
# Warning: 6.C.1_9886298_20081105_001.png not found!
# Warning: 6.C.1_9887703_20080617_001.png not found!
# Warning: 6.C.1_9889762_20081229_001.png not found!
# Warning: 6.E.1_9895555_20090421_001.png not found!
# Warning: 6.C.1_9896743_20081202_001.png not found!
# Warning: 6.C.1_9897397_20081212_001.png not found!
# Warning: 6.C.1_9900668_20080819_001.png not found!
# Warning: 6.C.1_9905156_20081013_001.png not found!
# Warning: 6.C.1_9906008_20090408_001.png not found!
# Warning: 6.E.1_9916274_20090519_001.png not found!
# Warning: 6.C.1_9917307_20081208_001.png not found!
# Warning: 6.C.1_9921811_20081229_001.png not found!
# Warning: 6.E.1_9923619_20090428_001.png not found!
# Warning: 6.C.1_9926839_20081203_001.png not found!
# Warning: 6.C.1_9928319_20081212_001.png not found!
# Warning: 6.C.1_9932809_20081028_001.png not found!
# Warning: 6.C.1_9937943_20081205_001.png not found!
# Warning: 6.C.1_9938236_20080926_001.png not found!
# Warning: 6.C.1_9943227_20080811_001.png not found!
# Warning: 6.C.1_9946330_20081217_001.png not found!
# Warning: 6.C.1_9947240_20080926_001.png not found!
# Warning: 6.C.1_9950954_20080910_001.png not found!
# Warning: 6.C.1_9953302_20081204_001.png not found!
# Warning: 6.C.1_9961728_20080910_001.png not found!
# Warning: 6.C.1_9961951_20081119_001.png not found!
# Warning: 6.C.1_9964731_20081013_001.png not found!
# Warning: 6.C.1_9967358_20081202_001.png not found!
# Warning: 6.C.1_9967815_20090122_001.png not found!
# Warning: 6.C.1_9967960_20081217_001.png not found!
# Warning: 6.C.1_9968283_20081230_001.png not found!
# Warning: 6.E.1_9976720_20090421_001.png not found!
# Warning: 6.E.1_9000099_20090728_001.png not found!
# Warning: 6.E.1_9022902_20090709_001.png not found!
# Warning: 6.C.1_9023193_20090630_001.png not found!
# Warning: 6.E.1_9049223_20090720_001.png not found!
# Warning: 6.E.1_9049706_20090706_001.png not found!
# Warning: 6.E.1_9062645_20090911_001.png not found!
# Warning: 6.E.1_9071463_20090921_001.png not found!
# Warning: 6.E.1_9076127_20090728_001.png not found!
# Warning: 6.E.1_9088414_20090821_001.png not found!
# Warning: 6.C.1_9109448_20090204_001.png not found!
# Warning: 6.E.1_9121285_20090612_001.png not found!
# Warning: 6.E.1_9122877_20090813_001.png not found!
# Warning: 6.E.1_9126260_20090923_001.png not found!
# Warning: 6.C.1_9129477_20090224_001.png not found!
# Warning: 6.E.1_9135342_20090922_001.png not found!
# Warning: 6.E.1_9143312_20090604_001.png not found!
# Warning: 6.E.1_9156789_20090616_001.png not found!
# Warning: 6.E.1_9160801_20090909_001.png not found!
# Warning: 6.C.1_9184588_20090406_001.png not found!
# Warning: 6.E.1_9211547_20090821_001.png not found!
# Warning: 6.E.1_9248932_20090810_001.png not found!
# Warning: 6.E.1_9281187_20090528_001.png not found!
# Warning: 6.C.1_9303539_20090312_001.png not found!
# Warning: 6.C.1_9307242_20090309_001.png not found!
# Warning: 6.E.1_9311154_20090924_001.png not found!
# Warning: 6.E.1_9353017_20090428_001.png not found!
# Warning: 6.E.1_9354015_20090520_001.png not found!
# Warning: 6.E.1_9362660_20100421_001.png not found!
# Warning: 6.E.1_9394203_20090731_001.png not found!
# Warning: 6.E.1_9402139_20090618_001.png not found!
# Warning: 6.E.1_9438523_20090917_001.png not found!
# Warning: 6.E.1_9438852_20100519_001.png not found!
# Warning: 6.E.1_9445105_20090514_001.png not found!
# Warning: 6.E.1_9456548_20100614_001.png not found!
# Warning: 6.E.1_9462532_20091016_001.png not found!
# Warning: 6.E.1_9467311_20090819_001.png not found!
# Warning: 6.E.1_9481413_20090716_001.png not found!
# Warning: 6.E.1_9484333_20090921_001.png not found!
# Warning: 6.E.1_9491365_20090609_001.png not found!
# Warning: 6.E.1_9496386_20090730_001.png not found!
# Warning: 6.E.1_9510375_20090713_001.png not found!
# Warning: 6.E.1_9512864_20090722_001.png not found!
# Warning: 6.E.1_9535384_20090702_001.png not found!
# Warning: 6.E.1_9539368_20090805_001.png not found!
# Warning: 6.E.1_9540125_20091214_001.png not found!
# Warning: 6.E.1_9547360_20090724_001.png not found!
# Warning: 6.E.1_9551857_20090630_001.png not found!
# Warning: 6.E.1_9555914_20090721_001.png not found!
# Warning: 6.E.1_9556402_20090713_001.png not found!
# Warning: 6.E.1_9561824_20090617_001.png not found!
# Warning: 6.E.1_9565513_20090612_001.png not found!
# Warning: 6.C.1_9577982_20090318_001.png not found!
# Warning: 6.E.1_9582223_20090824_001.png not found!
# Warning: 6.E.1_9585218_20100309_001.png not found!
# Warning: 6.E.1_9585931_20090720_001.png not found!
# Warning: 6.E.1_9595419_20090709_001.png not found!
# Warning: 6.E.1_9597241_20090619_001.png not found!
# Warning: 6.E.1_9610439_20090819_001.png not found!
# Warning: 6.E.1_9614934_20090901_001.png not found!
# Warning: 6.E.1_9619698_20091030_001.png not found!
# Warning: 6.E.1_9623679_20091117_001.png not found!
# Warning: 6.E.1_9626197_20090908_001.png not found!
# Warning: 6.E.1_9639388_20090902_001.png not found!
# Warning: 6.E.1_9641381_20090730_001.png not found!
# Warning: 6.E.1_9645683_20090828_001.png not found!
# Warning: 6.E.1_9647913_20091116_001.png not found!
# Warning: 6.E.1_9648073_20090504_001.png not found!
# Warning: 6.E.1_9679795_20100107_001.png not found!
# Warning: 6.E.1_9698137_20090826_001.png not found!
# Warning: 6.C.1_9716393_20090327_001.png not found!
# Warning: 6.C.1_9725081_20090415_001.png not found!
# Warning: 6.E.1_9750882_20090504_001.png not found!
# Warning: 6.C.1_9760954_20090427_001.png not found!
# Warning: 6.C.1_9768500_20090306_001.png not found!
# Warning: 6.C.1_9775009_20090408_001.png not found!
# Warning: 6.E.1_9785331_20100428_001.png not found!
# Warning: 6.C.1_9788072_20090420_001.png not found!
# Warning: 6.E.1_9796889_20091006_001.png not found!
# Warning: 6.C.1_9801148_20090319_001.png not found!
# Warning: 6.C.1_9808818_20090702_001.png not found!
# Warning: 6.C.1_9830316_20090220_001.png not found!
# Warning: 6.C.1_9837324_20090325_001.png not found!
# Warning: 6.E.1_9875303_20090813_001.png not found!
# Warning: 6.E.1_9880069_20100318_001.png not found!
# Warning: 6.E.1_9904541_20100405_001.png not found!
# Warning: 6.E.1_9904574_20100422_001.png not found!
# Warning: 6.E.1_9913281_20090923_001.png not found!
# Warning: 6.E.1_9943818_20090619_001.png not found!
# Warning: 6.E.1_9983309_20090603_001.png not found!
# Warning: 6.C.1_9003380_20090112_001.png not found!
# Warning: 6.C.1_9003406_20081121_001.png not found!
# Warning: 6.C.1_9007827_20080902_001.png not found!
# Warning: 6.E.1_9011918_20090722_001.png not found!
# Warning: 6.C.1_9014883_20090219_001.png not found!
# Warning: 6.C.1_9028786_20081021_001.png not found!
# Warning: 6.C.1_9036316_20081021_001.png not found!
# Warning: 6.E.1_9043507_20090603_001.png not found!
# Warning: 6.C.1_9054866_20080922_001.png not found!
# Warning: 6.C.1_9065272_20081209_001.png not found!
# Warning: 6.C.1_9068453_20090217_001.png not found!
# Warning: 6.C.1_9069786_20081107_001.png not found!
# Warning: 6.C.1_9091337_20090127_001.png not found!
# Warning: 6.E.1_9115049_20091123_001.png not found!
# Warning: 6.C.1_9122643_20090304_001.png not found!
# Warning: 6.E.1_9127864_20090817_001.png not found!
# Warning: 6.E.1_9133340_20090818_001.png not found!
# Warning: 6.C.1_9135902_20081024_001.png not found!
# Warning: 6.E.1_9156694_20091008_001.png not found!
# Warning: 6.E.1_9158391_20091023_001.png not found!
# Warning: 6.E.1_9201046_20090820_001.png not found!
# Warning: 6.C.1_9202456_20080930_001.png not found!
# Warning: 6.C.1_9211869_20090114_001.png not found!
# Warning: 6.C.1_9215390_20081103_001.png not found!
# Warning: 6.C.1_9233675_20090406_001.png not found!
# Warning: 6.C.1_9247140_20090311_001.png not found!
# Warning: 6.C.1_9268652_20090320_001.png not found!
# Warning: 6.C.1_9277151_20090225_001.png not found!
# Warning: 6.C.1_9279291_20081112_001.png not found!
# Warning: 6.E.1_9285212_20090521_001.png not found!
# Warning: 6.E.1_9290211_20090601_001.png not found!
# Warning: 6.C.1_9316405_20090407_001.png not found!
# Warning: 6.E.1_9321380_20090608_001.png not found!
# Warning: 6.C.1_9342351_20090225_001.png not found!
# Warning: 6.E.1_9357226_20090724_001.png not found!
# Warning: 6.C.1_9364232_20090317_001.png not found!
# Warning: 6.C.1_9368286_20090319_001.png not found!
# Warning: 6.C.1_9369286_20090413_001.png not found!
# Warning: 6.C.1_9381181_20090313_001.png not found!
# Warning: 6.C.1_9386858_20090313_001.png not found!
# Warning: 6.C.1_9397988_20081110_001.png not found!
# Warning: 6.C.1_9403165_20090701_001.png not found!
# Warning: 6.C.1_9404954_20090323_001.png not found!
# Warning: 6.C.1_9432102_20090106_001.png not found!
# Warning: 6.C.1_9432349_20090305_001.png not found!
# Warning: 6.C.1_9478060_20081022_001.png not found!
# Warning: 6.C.1_9481628_20090109_001.png not found!
# Warning: 6.C.1_9483254_20090108_001.png not found!
# Warning: 6.E.1_9484408_20090713_001.png not found!
# Warning: 6.C.1_9497534_20090303_001.png not found!
# Warning: 6.E.1_9508858_20090713_001.png not found!
# Warning: 6.E.1_9516844_20090729_001.png not found!
# Warning: 6.C.1_9537090_20080917_001.png not found!
# Warning: 6.C.1_9562591_20081124_001.png not found!
# Warning: 6.C.1_9581253_20081010_001.png not found!
# Warning: 6.E.1_9584925_20090923_001.png not found!
# Warning: 6.E.1_9592926_20090820_001.png not found!
# Warning: 6.C.1_9606664_20081210_001.png not found!
# Warning: 6.E.1_9621886_20090909_001.png not found!
# Warning: 6.E.1_9625433_20091001_001.png not found!
# Warning: 6.C.1_9625955_20080819_001.png not found!
# Warning: 6.E.1_9626432_20090818_001.png not found!
# Warning: 6.E.1_9636924_20090915_001.png not found!
# Warning: 6.C.1_9640119_20090217_001.png not found!
# Warning: 6.C.1_9650272_20081111_001.png not found!
# Warning: 6.C.1_9659472_20081211_001.png not found!
# Warning: 6.C.1_9659956_20080925_001.png not found!
# Warning: 6.C.1_9670700_20090209_001.png not found!
# Warning: 6.C.1_9688649_20081030_001.png not found!
# Warning: 6.C.1_9689788_20081120_001.png not found!
# Warning: 6.C.1_9693364_20090414_001.png not found!
# Warning: 6.C.1_9693806_20080924_001.png not found!
# Warning: 6.C.1_9699340_20081021_001.png not found!
# Warning: 6.C.1_9704858_20081028_001.png not found!
# Warning: 6.C.1_9708289_20081201_001.png not found!
# Warning: 6.E.1_9715480_20100122_001.png not found!
# Warning: 6.C.1_9723911_20081106_001.png not found!
# Warning: 6.C.1_9726418_20081015_001.png not found!
# Warning: 6.C.1_9727418_20081009_001.png not found!
# Warning: 6.C.1_9728920_20081029_001.png not found!
# Warning: 6.C.1_9729920_20080929_001.png not found!
# Warning: 6.C.1_9735403_20080825_001.png not found!
# Warning: 6.C.1_9745596_20080825_001.png not found!
# Warning: 6.C.1_9766072_20090319_001.png not found!
# Warning: 6.C.1_9777033_20090413_001.png not found!
# Warning: 6.C.1_9778632_20090417_001.png not found!
# Warning: 6.C.1_9785684_20081007_001.png not found!
# Warning: 6.E.1_9800285_20090430_001.png not found!
# Warning: 6.C.1_9800677_20081020_001.png not found!
# Warning: 6.C.1_9824274_20090224_001.png not found!
# Warning: 6.C.1_9844838_20081028_001.png not found!
# Warning: 6.C.1_9849372_20090320_001.png not found!
# Warning: 6.C.1_9855117_20081126_001.png not found!
# Warning: 6.C.1_9865818_20090401_001.png not found!
# Warning: 6.C.1_9867284_20081204_001.png not found!
# Warning: 6.C.1_9880321_20081113_001.png not found!
# Warning: 6.C.1_9886598_20090217_001.png not found!
# Warning: 6.C.1_9902900_20081117_001.png not found!
# Warning: 6.C.1_9903394_20081113_001.png not found!
# Warning: 6.C.1_9907909_20081022_001.png not found!
# Warning: 6.C.1_9910391_20090323_001.png not found!
# Warning: 6.C.1_9912946_20090116_001.png not found!
# Warning: 6.C.1_9917803_20090209_001.png not found!
# Warning: 6.C.1_9968924_20081201_001.png not found!
# Warning: 6.C.1_9973773_20090309_001.png not found!
# Warning: 6.C.1_9993846_20090109_001.png not found!
#   X_img_train shape: (377, 1764)
# Extracting validation image features...
# Warning: 6.E.1_9021102_20090706_001.png not found!
# Warning: 6.E.1_9030718_20090824_001.png not found!
# Warning: 6.E.1_9047519_20090720_001.png not found!
# Warning: 6.C.1_9048789_20090226_001.png not found!
# Warning: 6.E.1_9054972_20090911_001.png not found!
# Warning: 6.E.1_9066921_20090618_001.png not found!
# Warning: 6.E.1_9071669_20091120_001.png not found!
# Warning: 6.E.1_9072956_20090619_001.png not found!
# Warning: 6.E.1_9075939_20090911_001.png not found!
# Warning: 6.E.1_9075939_20091102_001.png not found!
# Warning: 6.E.1_9081635_20090818_001.png not found!
# Warning: 6.E.1_9082159_20100305_001.png not found!
# Warning: 6.E.1_9093108_20090921_001.png not found!
# Warning: 6.E.1_9113199_20090909_001.png not found!
# Warning: 6.E.1_9179789_20091005_001.png not found!
# Warning: 6.E.1_9193863_20091026_001.png not found!
# Warning: 6.C.1_9204055_20090319_001.png not found!
# Warning: 6.E.1_9252748_20100609_001.png not found!
# Warning: 6.C.1_9267648_20090529_001.png not found!
# Warning: 6.E.1_9267719_20100129_001.png not found!
# Warning: 6.E.1_9269275_20100608_001.png not found!
# Warning: 6.E.1_9318369_20090720_001.png not found!
# Warning: 6.E.1_9318527_20091022_001.png not found!
# Warning: 6.E.1_9326801_20100513_001.png not found!
# Warning: 6.E.1_9332345_20090618_001.png not found!
# Warning: 6.E.1_9353703_20100316_001.png not found!
# Warning: 6.E.1_9354699_20100322_001.png not found!
# Warning: 6.E.1_9359678_20100304_001.png not found!
# Warning: 6.E.1_9367965_20090513_001.png not found!
# Warning: 6.E.1_9378998_20090416_001.png not found!
# Warning: 6.E.1_9380143_20090612_001.png not found!
# Warning: 6.E.1_9392537_20100504_001.png not found!
# Warning: 6.E.1_9393527_20100525_001.png not found!
# Warning: 6.E.1_9405154_20090515_001.png not found!
# Warning: 6.E.1_9421492_20091105_001.png not found!
# Warning: 6.E.1_9423500_20090924_001.png not found!
# Warning: 6.E.1_9441528_20090811_001.png not found!
# Warning: 6.E.1_9451499_20090831_001.png not found!
# Warning: 6.E.1_9454284_20100305_001.png not found!
# Warning: 6.E.1_9463310_20090702_001.png not found!
# Warning: 6.E.1_9484850_20100405_001.png not found!
# Warning: 6.E.1_9495881_20100412_001.png not found!
# Warning: 6.E.1_9512848_20090527_001.png not found!
# Warning: 6.E.1_9517311_20090610_001.png not found!
# Warning: 6.E.1_9549139_20090515_001.png not found!
# Warning: 6.E.1_9560702_20090904_001.png not found!
# Warning: 6.E.1_9568504_20090723_001.png not found!
# Warning: 6.E.1_9574069_20090625_001.png not found!
# Warning: 6.E.1_9576572_20090811_001.png not found!
# Warning: 6.E.1_9592750_20090923_001.png not found!
# Warning: 6.E.1_9621208_20090804_001.png not found!
# Warning: 6.E.1_9627172_20091109_001.png not found!
# Warning: 6.E.1_9642569_20090928_001.png not found!
# Warning: 6.E.1_9643701_20091008_001.png not found!
# Warning: 6.E.1_9648265_20090717_001.png not found!
# Warning: 6.E.1_9746467_20090521_001.png not found!
# Warning: 6.E.1_9747567_20091013_001.png not found!
# Warning: 6.E.1_9768689_20091023_001.png not found!
# Warning: 6.E.1_9871046_20100429_001.png not found!
# Warning: 6.E.1_9873102_20100527_001.png not found!
# Warning: 6.E.1_9888515_20090505_001.png not found!
# Warning: 6.E.1_9894111_20100121_001.png not found!
# Warning: 6.E.1_9900971_20100308_001.png not found!
# Warning: 6.E.1_9905024_20100510_001.png not found!
# Warning: 6.E.1_9907544_20100416_001.png not found!
# Warning: 6.E.1_9908089_20100119_001.png not found!
# Warning: 6.E.1_9920140_20100426_001.png not found!
# Warning: 6.E.1_9946501_20100326_001.png not found!
# Warning: 6.E.1_9962749_20090629_001.png not found!
# Warning: 6.C.1_9967728_20090513_001.png not found!
# Warning: 6.E.1_9968721_20090630_001.png not found!
# Warning: 6.E.1_9973199_20090817_001.png not found!
# Warning: 6.E.1_9982186_20090608_001.png not found!
# Warning: 6.C.1_9004905_20081015_001.png not found!
# Warning: 6.C.1_9029913_20090219_001.png not found!
# Warning: 6.E.1_9044005_20090804_001.png not found!
# Warning: 6.E.1_9049507_20090930_001.png not found!
# Warning: 6.C.1_9076604_20080923_001.png not found!
# Warning: 6.C.1_9085290_20080819_001.png not found!
# Warning: 6.C.1_9088345_20090127_001.png not found!
# Warning: 6.C.1_9102297_20081002_001.png not found!
# Warning: 6.C.1_9102858_20090225_001.png not found!
# Warning: 6.C.1_9103365_20090206_001.png not found!
# Warning: 6.C.1_9103449_20090217_001.png not found!
# Warning: 6.C.1_9125977_20090223_001.png not found!
# Warning: 6.C.1_9134955_20090430_001.png not found!
# Warning: 6.C.1_9138965_20090428_001.png not found!
# Warning: 6.E.1_9155218_20100127_001.png not found!
# Warning: 6.C.1_9155449_20081029_001.png not found!
# Warning: 6.C.1_9210505_20090318_001.png not found!
# Warning: 6.C.1_9239552_20090130_001.png not found!
# Warning: 6.C.1_9273964_20090218_001.png not found!
# Warning: 6.C.1_9328376_20090224_001.png not found!
# Warning: 6.C.1_9332085_20081114_001.png not found!
# Warning: 6.C.1_9346354_20090325_001.png not found!
# Warning: 6.C.1_9355257_20090402_001.png not found!
# Warning: 6.C.1_9357383_20080916_001.png not found!
# Warning: 6.C.1_9372390_20081020_001.png not found!
# Warning: 6.C.1_9384158_20090303_001.png not found!
# Warning: 6.C.1_9390719_20081016_001.png not found!
# Warning: 6.C.1_9392241_20080902_001.png not found!
# Warning: 6.C.1_9414263_20090306_001.png not found!
# Warning: 6.E.1_9417544_20100604_001.png not found!
# Warning: 6.C.1_9434150_20090209_001.png not found!
# Warning: 6.C.1_9436383_20081003_001.png not found!
# Warning: 6.C.1_9454239_20080721_001.png not found!
# Warning: 6.C.1_9505796_20081119_001.png not found!
# Warning: 6.C.1_9519268_20090115_001.png not found!
# Warning: 6.C.1_9532533_20080912_001.png not found!
# Warning: 6.C.1_9542088_20080915_001.png not found!
# Warning: 6.C.1_9552108_20090316_001.png not found!
# Warning: 6.E.1_9552630_20090812_001.png not found!
# Warning: 6.C.1_9556608_20081201_001.png not found!
# Warning: 6.C.1_9557040_20080805_001.png not found!
# Warning: 6.C.1_9575145_20081112_001.png not found!
# Warning: 6.C.1_9585175_20090312_001.png not found!
# Warning: 6.C.1_9597680_20081001_001.png not found!
# Warning: 6.C.1_9599539_20080909_001.png not found!
# Warning: 6.C.1_9606507_20081023_001.png not found!
# Warning: 6.C.1_9615507_20080731_001.png not found!
# Warning: 6.C.1_9616501_20080911_001.png not found!
# Warning: 6.C.1_9622603_20080904_001.png not found!
# Warning: 6.C.1_9638953_20080911_001.png not found!
# Warning: 6.C.1_9639088_20090210_001.png not found!
# Warning: 6.C.1_9642550_20081002_001.png not found!
# Warning: 6.C.1_9643944_20080814_001.png not found!
# Warning: 6.C.1_9653966_20080904_001.png not found!
# Warning: 6.C.1_9662112_20081002_001.png not found!
# Warning: 6.C.1_9667637_20090116_001.png not found!
# Warning: 6.C.1_9682254_20090212_001.png not found!
# Warning: 6.C.1_9684122_20080902_001.png not found!
# Warning: 6.C.1_9686777_20081110_001.png not found!
# Warning: 6.C.1_9691663_20081114_001.png not found!
# Warning: 6.C.1_9693161_20080908_001.png not found!
# Warning: 6.C.1_9727780_20080918_001.png not found!
# Warning: 6.C.1_9740440_20081215_001.png not found!
# Warning: 6.C.1_9743354_20080909_001.png not found!
# Warning: 6.C.1_9745458_20081020_001.png not found!
# Warning: 6.C.1_9751401_20081022_001.png not found!
# Warning: 6.C.1_9757418_20081031_001.png not found!
# Warning: 6.C.1_9758941_20081030_001.png not found!
# Warning: 6.C.1_9761431_20090114_001.png not found!
# Warning: 6.C.1_9771624_20090109_001.png not found!
# Warning: 6.C.1_9785604_20081010_001.png not found!
# Warning: 6.C.1_9789095_20081117_001.png not found!
# Warning: 6.C.1_9790623_20081013_001.png not found!
# Warning: 6.C.1_9818359_20090105_001.png not found!
# Warning: 6.C.1_9824005_20080820_001.png not found!
# Warning: 6.C.1_9845361_20081008_001.png not found!
# Warning: 6.C.1_9866291_20081119_001.png not found!
# Warning: 6.C.1_9884303_20081029_001.png not found!
# Warning: 6.C.1_9886298_20081105_001.png not found!
# Warning: 6.C.1_9887703_20080617_001.png not found!
# Warning: 6.C.1_9889762_20081229_001.png not found!
# Warning: 6.E.1_9895555_20090421_001.png not found!
# Warning: 6.C.1_9896743_20081202_001.png not found!
# Warning: 6.C.1_9897397_20081212_001.png not found!
# Warning: 6.C.1_9900668_20080819_001.png not found!
# Warning: 6.C.1_9905156_20081013_001.png not found!
# Warning: 6.C.1_9906008_20090408_001.png not found!
# Warning: 6.E.1_9916274_20090519_001.png not found!
# Warning: 6.C.1_9917307_20081208_001.png not found!
# Warning: 6.C.1_9921811_20081229_001.png not found!
# Warning: 6.E.1_9923619_20090428_001.png not found!
# Warning: 6.C.1_9926839_20081203_001.png not found!
# Warning: 6.C.1_9928319_20081212_001.png not found!
# Warning: 6.C.1_9932809_20081028_001.png not found!
# Warning: 6.C.1_9937943_20081205_001.png not found!
# Warning: 6.C.1_9938236_20080926_001.png not found!
# Warning: 6.C.1_9943227_20080811_001.png not found!
# Warning: 6.C.1_9946330_20081217_001.png not found!
# Warning: 6.C.1_9947240_20080926_001.png not found!
# Warning: 6.C.1_9950954_20080910_001.png not found!
# Warning: 6.C.1_9953302_20081204_001.png not found!
# Warning: 6.C.1_9961728_20080910_001.png not found!
# Warning: 6.C.1_9961951_20081119_001.png not found!
# Warning: 6.C.1_9964731_20081013_001.png not found!
# Warning: 6.C.1_9967358_20081202_001.png not found!
# Warning: 6.C.1_9967815_20090122_001.png not found!
# Warning: 6.C.1_9967960_20081217_001.png not found!
# Warning: 6.C.1_9968283_20081230_001.png not found!
# Warning: 6.E.1_9976720_20090421_001.png not found!
# Warning: 6.E.1_9000099_20090728_001.png not found!
# Warning: 6.E.1_9022902_20090709_001.png not found!
# Warning: 6.C.1_9023193_20090630_001.png not found!
# Warning: 6.E.1_9049223_20090720_001.png not found!
# Warning: 6.E.1_9049706_20090706_001.png not found!
# Warning: 6.E.1_9062645_20090911_001.png not found!
# Warning: 6.E.1_9071463_20090921_001.png not found!
# Warning: 6.E.1_9076127_20090728_001.png not found!
# Warning: 6.E.1_9088414_20090821_001.png not found!
# Warning: 6.C.1_9109448_20090204_001.png not found!
# Warning: 6.E.1_9121285_20090612_001.png not found!
# Warning: 6.E.1_9122877_20090813_001.png not found!
# Warning: 6.E.1_9126260_20090923_001.png not found!
# Warning: 6.C.1_9129477_20090224_001.png not found!
# Warning: 6.E.1_9135342_20090922_001.png not found!
# Warning: 6.E.1_9143312_20090604_001.png not found!
# Warning: 6.E.1_9156789_20090616_001.png not found!
# Warning: 6.E.1_9160801_20090909_001.png not found!
# Warning: 6.C.1_9184588_20090406_001.png not found!
# Warning: 6.E.1_9211547_20090821_001.png not found!
# Warning: 6.E.1_9248932_20090810_001.png not found!
# Warning: 6.E.1_9281187_20090528_001.png not found!
# Warning: 6.C.1_9303539_20090312_001.png not found!
# Warning: 6.C.1_9307242_20090309_001.png not found!
# Warning: 6.E.1_9311154_20090924_001.png not found!
# Warning: 6.E.1_9353017_20090428_001.png not found!
# Warning: 6.E.1_9354015_20090520_001.png not found!
# Warning: 6.E.1_9362660_20100421_001.png not found!
# Warning: 6.E.1_9394203_20090731_001.png not found!
# Warning: 6.E.1_9402139_20090618_001.png not found!
# Warning: 6.E.1_9438523_20090917_001.png not found!
# Warning: 6.E.1_9438852_20100519_001.png not found!
# Warning: 6.E.1_9445105_20090514_001.png not found!
# Warning: 6.E.1_9456548_20100614_001.png not found!
# Warning: 6.E.1_9462532_20091016_001.png not found!
# Warning: 6.E.1_9467311_20090819_001.png not found!
# Warning: 6.E.1_9481413_20090716_001.png not found!
# Warning: 6.E.1_9484333_20090921_001.png not found!
# Warning: 6.E.1_9491365_20090609_001.png not found!
# Warning: 6.E.1_9496386_20090730_001.png not found!
# Warning: 6.E.1_9510375_20090713_001.png not found!
# Warning: 6.E.1_9512864_20090722_001.png not found!
# Warning: 6.E.1_9535384_20090702_001.png not found!
# Warning: 6.E.1_9539368_20090805_001.png not found!
# Warning: 6.E.1_9540125_20091214_001.png not found!
# Warning: 6.E.1_9547360_20090724_001.png not found!
# Warning: 6.E.1_9551857_20090630_001.png not found!
# Warning: 6.E.1_9555914_20090721_001.png not found!
# Warning: 6.E.1_9556402_20090713_001.png not found!
# Warning: 6.E.1_9561824_20090617_001.png not found!
# Warning: 6.E.1_9565513_20090612_001.png not found!
# Warning: 6.C.1_9577982_20090318_001.png not found!
# Warning: 6.E.1_9582223_20090824_001.png not found!
# Warning: 6.E.1_9585218_20100309_001.png not found!
# Warning: 6.E.1_9585931_20090720_001.png not found!
# Warning: 6.E.1_9595419_20090709_001.png not found!
# Warning: 6.E.1_9597241_20090619_001.png not found!
# Warning: 6.E.1_9610439_20090819_001.png not found!
# Warning: 6.E.1_9614934_20090901_001.png not found!
# Warning: 6.E.1_9619698_20091030_001.png not found!
# Warning: 6.E.1_9623679_20091117_001.png not found!
# Warning: 6.E.1_9626197_20090908_001.png not found!
# Warning: 6.E.1_9639388_20090902_001.png not found!
# Warning: 6.E.1_9641381_20090730_001.png not found!
# Warning: 6.E.1_9645683_20090828_001.png not found!
# Warning: 6.E.1_9647913_20091116_001.png not found!
# Warning: 6.E.1_9648073_20090504_001.png not found!
# Warning: 6.E.1_9679795_20100107_001.png not found!
# Warning: 6.E.1_9698137_20090826_001.png not found!
# Warning: 6.C.1_9716393_20090327_001.png not found!
# Warning: 6.C.1_9725081_20090415_001.png not found!
# Warning: 6.E.1_9750882_20090504_001.png not found!
# Warning: 6.C.1_9760954_20090427_001.png not found!
# Warning: 6.C.1_9768500_20090306_001.png not found!
# Warning: 6.C.1_9775009_20090408_001.png not found!
# Warning: 6.E.1_9785331_20100428_001.png not found!
# Warning: 6.C.1_9788072_20090420_001.png not found!
# Warning: 6.E.1_9796889_20091006_001.png not found!
# Warning: 6.C.1_9801148_20090319_001.png not found!
# Warning: 6.C.1_9808818_20090702_001.png not found!
# Warning: 6.C.1_9830316_20090220_001.png not found!
# Warning: 6.C.1_9837324_20090325_001.png not found!
# Warning: 6.E.1_9875303_20090813_001.png not found!
# Warning: 6.E.1_9880069_20100318_001.png not found!
# Warning: 6.E.1_9904541_20100405_001.png not found!
# Warning: 6.E.1_9904574_20100422_001.png not found!
# Warning: 6.E.1_9913281_20090923_001.png not found!
# Warning: 6.E.1_9943818_20090619_001.png not found!
# Warning: 6.E.1_9983309_20090603_001.png not found!
# Warning: 6.C.1_9003380_20090112_001.png not found!
# Warning: 6.C.1_9003406_20081121_001.png not found!
# Warning: 6.C.1_9007827_20080902_001.png not found!
# Warning: 6.E.1_9011918_20090722_001.png not found!
# Warning: 6.C.1_9014883_20090219_001.png not found!
# Warning: 6.C.1_9028786_20081021_001.png not found!
# Warning: 6.C.1_9036316_20081021_001.png not found!
# Warning: 6.E.1_9043507_20090603_001.png not found!
# Warning: 6.C.1_9054866_20080922_001.png not found!
# Warning: 6.C.1_9065272_20081209_001.png not found!
# Warning: 6.C.1_9068453_20090217_001.png not found!
# Warning: 6.C.1_9069786_20081107_001.png not found!
# Warning: 6.C.1_9091337_20090127_001.png not found!
# Warning: 6.E.1_9115049_20091123_001.png not found!
# Warning: 6.C.1_9122643_20090304_001.png not found!
# Warning: 6.E.1_9127864_20090817_001.png not found!
# Warning: 6.E.1_9133340_20090818_001.png not found!
# Warning: 6.C.1_9135902_20081024_001.png not found!
# Warning: 6.E.1_9156694_20091008_001.png not found!
# Warning: 6.E.1_9158391_20091023_001.png not found!
# Warning: 6.E.1_9201046_20090820_001.png not found!
# Warning: 6.C.1_9202456_20080930_001.png not found!
# Warning: 6.C.1_9211869_20090114_001.png not found!
# Warning: 6.C.1_9215390_20081103_001.png not found!
# Warning: 6.C.1_9233675_20090406_001.png not found!
# Warning: 6.C.1_9247140_20090311_001.png not found!
# Warning: 6.C.1_9268652_20090320_001.png not found!
# Warning: 6.C.1_9277151_20090225_001.png not found!
# Warning: 6.C.1_9279291_20081112_001.png not found!
# Warning: 6.E.1_9285212_20090521_001.png not found!
# Warning: 6.E.1_9290211_20090601_001.png not found!
# Warning: 6.C.1_9316405_20090407_001.png not found!
# Warning: 6.E.1_9321380_20090608_001.png not found!
# Warning: 6.C.1_9342351_20090225_001.png not found!
# Warning: 6.E.1_9357226_20090724_001.png not found!
# Warning: 6.C.1_9364232_20090317_001.png not found!
# Warning: 6.C.1_9368286_20090319_001.png not found!
# Warning: 6.C.1_9369286_20090413_001.png not found!
# Warning: 6.C.1_9381181_20090313_001.png not found!
# Warning: 6.C.1_9386858_20090313_001.png not found!
# Warning: 6.C.1_9397988_20081110_001.png not found!
# Warning: 6.C.1_9403165_20090701_001.png not found!
# Warning: 6.C.1_9404954_20090323_001.png not found!
# Warning: 6.C.1_9432102_20090106_001.png not found!
# Warning: 6.C.1_9432349_20090305_001.png not found!
# Warning: 6.C.1_9478060_20081022_001.png not found!
# Warning: 6.C.1_9481628_20090109_001.png not found!
# Warning: 6.C.1_9483254_20090108_001.png not found!
# Warning: 6.E.1_9484408_20090713_001.png not found!
# Warning: 6.C.1_9497534_20090303_001.png not found!
# Warning: 6.E.1_9508858_20090713_001.png not found!
# Warning: 6.E.1_9516844_20090729_001.png not found!
# Warning: 6.C.1_9537090_20080917_001.png not found!
# Warning: 6.C.1_9562591_20081124_001.png not found!
# Warning: 6.C.1_9581253_20081010_001.png not found!
# Warning: 6.E.1_9584925_20090923_001.png not found!
# Warning: 6.E.1_9592926_20090820_001.png not found!
# Warning: 6.C.1_9606664_20081210_001.png not found!
# Warning: 6.E.1_9621886_20090909_001.png not found!
# Warning: 6.E.1_9625433_20091001_001.png not found!
# Warning: 6.C.1_9625955_20080819_001.png not found!
# Warning: 6.E.1_9626432_20090818_001.png not found!
# Warning: 6.E.1_9636924_20090915_001.png not found!
# Warning: 6.C.1_9640119_20090217_001.png not found!
# Warning: 6.C.1_9650272_20081111_001.png not found!
# Warning: 6.C.1_9659472_20081211_001.png not found!
# Warning: 6.C.1_9659956_20080925_001.png not found!
# Warning: 6.C.1_9670700_20090209_001.png not found!
# Warning: 6.C.1_9688649_20081030_001.png not found!
# Warning: 6.C.1_9689788_20081120_001.png not found!
# Warning: 6.C.1_9693364_20090414_001.png not found!
# Warning: 6.C.1_9693806_20080924_001.png not found!
# Warning: 6.C.1_9699340_20081021_001.png not found!
# Warning: 6.C.1_9704858_20081028_001.png not found!
# Warning: 6.C.1_9708289_20081201_001.png not found!
# Warning: 6.E.1_9715480_20100122_001.png not found!
# Warning: 6.C.1_9723911_20081106_001.png not found!
# Warning: 6.C.1_9726418_20081015_001.png not found!
# Warning: 6.C.1_9727418_20081009_001.png not found!
# Warning: 6.C.1_9728920_20081029_001.png not found!
# Warning: 6.C.1_9729920_20080929_001.png not found!
# Warning: 6.C.1_9735403_20080825_001.png not found!
# Warning: 6.C.1_9745596_20080825_001.png not found!
# Warning: 6.C.1_9766072_20090319_001.png not found!
# Warning: 6.C.1_9777033_20090413_001.png not found!
# Warning: 6.C.1_9778632_20090417_001.png not found!
# Warning: 6.C.1_9785684_20081007_001.png not found!
# Warning: 6.E.1_9800285_20090430_001.png not found!
# Warning: 6.C.1_9800677_20081020_001.png not found!
# Warning: 6.C.1_9824274_20090224_001.png not found!
# Warning: 6.C.1_9844838_20081028_001.png not found!
# Warning: 6.C.1_9849372_20090320_001.png not found!
# Warning: 6.C.1_9855117_20081126_001.png not found!
# Warning: 6.C.1_9865818_20090401_001.png not found!
# Warning: 6.C.1_9867284_20081204_001.png not found!
# Warning: 6.C.1_9880321_20081113_001.png not found!
# Warning: 6.C.1_9886598_20090217_001.png not found!
# Warning: 6.C.1_9902900_20081117_001.png not found!
# Warning: 6.C.1_9903394_20081113_001.png not found!
# Warning: 6.C.1_9907909_20081022_001.png not found!
# Warning: 6.C.1_9910391_20090323_001.png not found!
# Warning: 6.C.1_9912946_20090116_001.png not found!
# Warning: 6.C.1_9917803_20090209_001.png not found!
# Warning: 6.C.1_9968924_20081201_001.png not found!
# Warning: 6.C.1_9973773_20090309_001.png not found!
# Warning: 6.C.1_9993846_20090109_001.png not found!
#   X_img_val shape:   (377, 1764)
# Preparing training metadata...
#   X_meta_train shape: (377, 2)
# Preparing validation metadata...
#   X_meta_val shape:   (377, 2)
# Feature extraction completed.

# %% [markdown]
# <br>

# %% [markdown]
# # 7 - Combine Image Features and Metadata
#
# explain

# %%
X_train = np.hstack([X_img_train, X_meta_train])
X_val   = np.hstack([X_img_val,   X_meta_val])
y_train = train_df["BMD"].values
y_val   = val_df["BMD"].values

print(f"Combined train shape: {X_train.shape}")
print(f"Combined val shape:   {X_val.shape}")
print(f"y_train shape:        {y_train.shape}")
# Out:
# Combined train shape: (377, 1766)
# Combined val shape:   (377, 1766)
# y_train shape:        (377,)

# %% [markdown]
# # 8 - Pipeline Scaling
#
# explain

# %%
from sklearn.ensemble import RandomForestRegressor

pipeline = Pipeline([
    # Standardise features
    ("scaler", StandardScaler()),
    # Reduce high-dimensional image features
    ("pca", PCA(n_components=50, random_state=RANDOM_STATE)),
    # [Disara] Random Forest model
    ('model', RandomForestRegressor(n_estimators=100, random_state=RANDOM_STATE))
])

param_grid = {
    "pca__n_components": [30, 50, 75, 100],
    "model__n_estimators": [50, 100, 200],
    "model__max_depth": [None, 5, 10],
    "model__max_features": ["sqrt", "log2"]
}

# 5 fold cross validation
cv = KFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

# grid search
search = RandomizedSearchCV(
    pipeline,
    param_grid,
    n_iter=20,
    scoring="neg_mean_absolute_error",
    cv=cv,
    n_jobs=1,
    verbose=4,
    refit=True,
)

# model training
import joblib
with joblib.parallel_backend("threading"):
    search.fit(X_train, y_train)

print("\n=== Best CV result ===")
print(f"Best CV MAE: {-search.best_score_:.4f}")
print(f"Best params: {search.best_params_}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=100, pca__n_components=30;, score=-0.128 total time=   0.4s
# [CV 2/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=100, pca__n_components=30;, score=-0.138 total time=   0.3s
# [CV 3/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=100, pca__n_components=30;, score=-0.101 total time=   0.5s
# [CV 4/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=100, pca__n_components=30;, score=-0.129 total time=   0.7s
# [CV 5/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=100, pca__n_components=30;, score=-0.105 total time=   0.7s
# [CV 1/5] END model__max_depth=10, model__max_features=log2, model__n_estimators=50, pca__n_components=75;, score=-0.109 total time=   0.8s
# [CV 2/5] END model__max_depth=10, model__max_features=log2, model__n_estimators=50, pca__n_components=75;, score=-0.139 total time=   0.7s
# [CV 3/5] END model__max_depth=10, model__max_features=log2, model__n_estimators=50, pca__n_components=75;, score=-0.111 total time=   0.2s
# [CV 4/5] END model__max_depth=10, model__max_features=log2, model__n_estimators=50, pca__n_components=75;, score=-0.132 total time=   0.4s
# [CV 5/5] END model__max_depth=10, model__max_features=log2, model__n_estimators=50, pca__n_components=75;, score=-0.107 total time=   0.2s
# [CV 1/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=100, pca__n_components=75;, score=-0.109 total time=   0.6s
# [CV 2/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=100, pca__n_components=75;, score=-0.141 total time=   0.4s
# [CV 3/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=100, pca__n_components=75;, score=-0.114 total time=   0.4s
# [CV 4/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=100, pca__n_components=75;, score=-0.133 total time=   0.5s
# [CV 5/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=100, pca__n_components=75;, score=-0.106 total time=   0.4s
# [CV 1/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=50, pca__n_components=30;, score=-0.138 total time=   0.3s
# [CV 2/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=50, pca__n_components=30;, score=-0.142 total time=   0.4s
# [CV 3/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=50, pca__n_components=30;, score=-0.102 total time=   0.2s
# [CV 4/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=50, pca__n_components=30;, score=-0.130 total time=   0.4s
# [CV 5/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=50, pca__n_components=30;, score=-0.104 total time=   0.2s
# [CV 1/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=100, pca__n_components=30;, score=-0.112 total time=   0.3s
# [CV 2/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=100, pca__n_components=30;, score=-0.135 total time=   0.3s
# [CV 3/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=100, pca__n_components=30;, score=-0.101 total time=   0.4s
# [CV 4/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=100, pca__n_components=30;, score=-0.129 total time=   0.3s
# [CV 5/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=100, pca__n_components=30;, score=-0.105 total time=   0.4s
# [CV 1/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=50, pca__n_components=75;, score=-0.115 total time=   0.3s
# [CV 2/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=50, pca__n_components=75;, score=-0.138 total time=   0.4s
# [CV 3/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=50, pca__n_components=75;, score=-0.120 total time=   0.3s
# [CV 4/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=50, pca__n_components=75;, score=-0.132 total time=   0.3s
# [CV 5/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=50, pca__n_components=75;, score=-0.109 total time=   0.3s
# [CV 1/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=200, pca__n_components=75;, score=-0.110 total time=   0.6s
# [CV 2/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=200, pca__n_components=75;, score=-0.141 total time=   0.8s
# [CV 3/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=200, pca__n_components=75;, score=-0.111 total time=   0.6s
# [CV 4/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=200, pca__n_components=75;, score=-0.133 total time=   1.2s
# [CV 5/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=200, pca__n_components=75;, score=-0.106 total time=   1.6s
# [CV 1/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=200, pca__n_components=75;, score=-0.109 total time=   0.6s
# [CV 2/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=200, pca__n_components=75;, score=-0.140 total time=   0.5s
# [CV 3/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=200, pca__n_components=75;, score=-0.114 total time=   0.7s
# [CV 4/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=200, pca__n_components=75;, score=-0.132 total time=   0.8s
# [CV 5/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=200, pca__n_components=75;, score=-0.106 total time=   0.5s
# [CV 1/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=50, pca__n_components=30;, score=-0.136 total time=   0.3s
# [CV 2/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=50, pca__n_components=30;, score=-0.142 total time=   0.2s
# [CV 3/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=50, pca__n_components=30;, score=-0.107 total time=   0.3s
# [CV 4/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=50, pca__n_components=30;, score=-0.127 total time=   0.3s
# [CV 5/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=50, pca__n_components=30;, score=-0.108 total time=   0.2s
# [CV 1/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=100, pca__n_components=75;, score=-0.110 total time=   0.4s
# [CV 2/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=100, pca__n_components=75;, score=-0.137 total time=   0.6s
# [CV 3/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=100, pca__n_components=75;, score=-0.119 total time=   0.4s
# [CV 4/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=100, pca__n_components=75;, score=-0.132 total time=   0.6s
# [CV 5/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=100, pca__n_components=75;, score=-0.108 total time=   0.4s
# [CV 1/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=200, pca__n_components=100;, score=-0.111 total time=   0.8s
# [CV 2/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=200, pca__n_components=100;, score=-0.139 total time=   0.5s
# [CV 3/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=200, pca__n_components=100;, score=-0.115 total time=   0.6s
# [CV 4/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=200, pca__n_components=100;, score=-0.130 total time=   0.7s
# [CV 5/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=200, pca__n_components=100;, score=-0.118 total time=   0.5s
# [CV 1/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=100, pca__n_components=100;, score=-0.111 total time=   0.7s
# [CV 2/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=100, pca__n_components=100;, score=-0.140 total time=   1.2s
# [CV 3/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=100, pca__n_components=100;, score=-0.116 total time=   1.1s
# [CV 4/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=100, pca__n_components=100;, score=-0.130 total time=   0.6s
# [CV 5/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=100, pca__n_components=100;, score=-0.118 total time=   0.6s
# [CV 1/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=200, pca__n_components=50;, score=-0.109 total time=   0.7s
# [CV 2/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=200, pca__n_components=50;, score=-0.138 total time=   0.6s
# [CV 3/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=200, pca__n_components=50;, score=-0.103 total time=   0.6s
# [CV 4/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=200, pca__n_components=50;, score=-0.132 total time=   0.6s
# [CV 5/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=200, pca__n_components=50;, score=-0.107 total time=   0.8s
# [CV 1/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=200, pca__n_components=50;, score=-0.109 total time=   0.5s
# [CV 2/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=200, pca__n_components=50;, score=-0.139 total time=   0.7s
# [CV 3/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=200, pca__n_components=50;, score=-0.104 total time=   0.7s
# [CV 4/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=200, pca__n_components=50;, score=-0.132 total time=   0.5s
# [CV 5/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=200, pca__n_components=50;, score=-0.107 total time=   0.5s
# [CV 1/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=100, pca__n_components=50;, score=-0.108 total time=   0.4s
# [CV 2/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=100, pca__n_components=50;, score=-0.140 total time=   0.4s
# [CV 3/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=100, pca__n_components=50;, score=-0.105 total time=   0.4s
# [CV 4/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=100, pca__n_components=50;, score=-0.133 total time=   0.4s
# [CV 5/5] END model__max_depth=None, model__max_features=sqrt, model__n_estimators=100, pca__n_components=50;, score=-0.109 total time=   0.5s
# [CV 1/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=200, pca__n_components=75;, score=-0.109 total time=   0.8s
# [CV 2/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=200, pca__n_components=75;, score=-0.140 total time=   1.3s
# [CV 3/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=200, pca__n_components=75;, score=-0.114 total time=   1.7s
# [CV 4/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=200, pca__n_components=75;, score=-0.132 total time=   0.6s
# [CV 5/5] END model__max_depth=None, model__max_features=log2, model__n_estimators=200, pca__n_components=75;, score=-0.105 total time=   0.7s
# [CV 1/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=200, pca__n_components=30;, score=-0.121 total time=   0.5s
# [CV 2/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=200, pca__n_components=30;, score=-0.137 total time=   0.5s
# [CV 3/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=200, pca__n_components=30;, score=-0.101 total time=   0.5s
# [CV 4/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=200, pca__n_components=30;, score=-0.129 total time=   0.5s
# [CV 5/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=200, pca__n_components=30;, score=-0.104 total time=   0.6s
# [CV 1/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=50, pca__n_components=50;, score=-0.108 total time=   0.2s
# [CV 2/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=50, pca__n_components=50;, score=-0.137 total time=   0.2s
# [CV 3/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=50, pca__n_components=50;, score=-0.104 total time=   0.4s
# [CV 4/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=50, pca__n_components=50;, score=-0.128 total time=   0.2s
# [CV 5/5] END model__max_depth=10, model__max_features=sqrt, model__n_estimators=50, pca__n_components=50;, score=-0.108 total time=   0.3s
# [CV 1/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=200, pca__n_components=50;, score=-0.108 total time=   0.7s
# [CV 2/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=200, pca__n_components=50;, score=-0.139 total time=   0.5s
# [CV 3/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=200, pca__n_components=50;, score=-0.103 total time=   0.7s
# [CV 4/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=200, pca__n_components=50;, score=-0.131 total time=   0.5s
# [CV 5/5] END model__max_depth=5, model__max_features=sqrt, model__n_estimators=200, pca__n_components=50;, score=-0.107 total time=   0.6s
# [CV 1/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=50, pca__n_components=100;, score=-0.111 total time=   0.5s
# [CV 2/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=50, pca__n_components=100;, score=-0.140 total time=   0.3s
# [CV 3/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=50, pca__n_components=100;, score=-0.117 total time=   0.5s
# [CV 4/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=50, pca__n_components=100;, score=-0.132 total time=   0.4s
# [CV 5/5] END model__max_depth=5, model__max_features=log2, model__n_estimators=50, pca__n_components=100;, score=-0.119 total time=   0.6s
#
# === Best CV result ===
# Best CV MAE: 0.1163
# Best params: {'pca__n_components': 30, 'model__n_estimators': 100, 'model__max_features': 'sqrt', 'model__max_depth': 5}

# %% [markdown]
# # 9 - Regression Evaluation
#
# The best model from the grid search is evaluated on both the training set (to diagnose overfitting) and the held-out validation set (to estimate real-world performance).
#
# <h5 align="center">Reported metrics:</h5>
#
# | Metric | Interpretation |
# |---|---|
# | **MAE** | Mean absolute error |
# | **MSE** | Mean squared error (penalises large errors more heavily) |
# | **RMSE** | Square root of MSE |
# | **R²** | Proportion of BMD variance explained (1.0 = perfect) |

# %%
best_model = search.best_estimator_

y_pred_train = best_model.predict(X_train)
y_pred_val   = best_model.predict(X_val)

def regression_report(y_true, y_pred, label):
    mae  = mean_absolute_error(y_true, y_pred)
    mse  = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2   = r2_score(y_true, y_pred)
    print(f"--- {label} ---")
    print(f"  MAE  = {mae:.4f}")
    print(f"  MSE  = {mse:.6f}")
    print(f"  RMSE = {rmse:.4f}")
    print(f"  R²   = {r2:.4f}")
    return {"MAE": mae, "MSE": mse, "RMSE": rmse, "R2": r2}

train_metrics = regression_report(y_train, y_pred_train, "Training set")
print()
val_metrics   = regression_report(y_val,   y_pred_val,   "Validation set")

# %% [markdown]
# # 10 - Diagnostic Plots
#
# explain

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Predicted vs actual on validation
axes[0].scatter(y_val, y_pred_val, alpha=0.7, color="steelblue", edgecolor="white")
lo, hi = min(y_val.min(), y_pred_val.min()), max(y_val.max(), y_pred_val.max())
axes[0].plot([lo, hi], [lo, hi], "r--", label="Perfect prediction")
axes[0].set_xlabel("Actual BMD")
axes[0].set_ylabel("Predicted BMD")
axes[0].set_title("Validation: predicted vs actual")
axes[0].legend()

# Residual plot
residuals = y_val - y_pred_val
axes[1].scatter(y_pred_val, residuals, alpha=0.7, color="darkorange", edgecolor="white")
axes[1].axhline(0, color="red", linestyle="--")
axes[1].set_xlabel("Predicted BMD")
axes[1].set_ylabel("Residual (actual − predicted)")
axes[1].set_title("Validation: residuals")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 11 - Convert Predicted BMD
#
# explain
#
# nb: maybe remove this section?

# %%
# Convert predicted BMD into T-scores and binary labels
T_pred_val = (y_pred_val - REF_BMD) / REF_SD
label_pred_val = np.where(T_pred_val >= -1.0, 0, 1)

# True labels already exist from EDA
label_true_val = val_df["low_bmd"].values

results_df = pd.DataFrame({
    "filename": val_df["image"].values,
    "true_BMD": y_val.round(4),
    "pred_BMD": y_pred_val.round(4),
    "true_T": val_df["t_score"].values.round(3),
    "pred_T": T_pred_val.round(3),
    "true_label": label_true_val,
    "pred_label": label_pred_val,
})

results_df.head(15)

# %% [markdown]
# # 12 - Evaluation
#
# explain

# %%
#Confusion Matrix

labels_order = ["0", "1"]
cm = confusion_matrix(label_true_val, label_pred_val, labels=labels_order)

# Print confusion matrix
print("Confusion matrix (rows = true, cols = predicted):")
print(pd.DataFrame(cm, index=labels_order, columns=labels_order))

# Sensitivity and specificity
TN, FP, FN, TP = cm[0, 0], cm[0, 1], cm[1, 0], cm[1, 1]
sensitivity = TP / (TP + FN) if (TP + FN) > 0 else float("nan")
specificity = TN / (TN + FP) if (TN + FP) > 0 else float("nan")
bal_acc     = balanced_accuracy_score(label_true_val, label_pred_val)

print(f"\nSensitivity (Low BMD recall):  {sensitivity:.3f}")
print(f"Specificity (Normal recall):   {specificity:.3f}")
print(f"Balanced accuracy:             {bal_acc:.3f}")

print("\nFull classification report:")
print(classification_report(label_true_val, label_pred_val, labels=labels_order, zero_division=0))

# Heatmap visualisation
fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=labels_order, yticklabels=labels_order, ax=ax)
ax.set_xlabel("Predicted")
ax.set_ylabel("True")
ax.set_title("Validation confusion matrix")
plt.tight_layout(); plt.show()
